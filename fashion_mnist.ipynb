# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas
from sklearn.metrics import accuracy_score
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
data = keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)=data.load_data()

# %%
#train_images=train_images/255.0
#test_images=test_images/255.0

# %%
model=keras.Sequential(
    [
     keras.layers.Flatten(input_shape=(28,28)),
     keras.layers.Dense(128,activation='relu'),
     keras.layers.Dense(10,activation='softmax'),
    ]
)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images,train_labels,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.5493 - accuracy: 0.6837
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7507 - accuracy: 0.7191
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6309 - accuracy: 0.7574
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5691 - accuracy: 0.7878
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5303 - accuracy: 0.8079

# %%
test_loss,test_acc=model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.5512 - accuracy: 0.7966

# %%
predict=model.predict(test_images)

print(class_names[np.argmax(predict[5])])
# Out:
# Trouser

# %%
for i in range(5):
  plt.grid()
 
  plt.imshow(test_images[i])
 
  plt.xlabel('Predicted:'+ class_names[np.argmax(predict[i])])
  plt.title('Actual:'+class_names[test_labels[i]])
  plt.show()
